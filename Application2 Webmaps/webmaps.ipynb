# %%
import pandas
import folium

# %%
voldata=pandas.read_csv("Volcanoes_USA.txt")

# %%
voldata
# Out:
#     VOLCANX020    NUMBER                     NAME       LOCATION  \
# 0        509.0  1201-01=                    Baker  US-Washington
# 1        511.0  1201-02-             Glacier Peak  US-Washington
# 2        513.0  1201-03-                  Rainier  US-Washington
# 3        515.0  1201-05-               St. Helens  US-Washington
# 4        516.0  1201-04-                    Adams  US-Washington
# 5        517.0  1201-06-              West Crater  US-Washington
# 6        518.0  1201-07-            Indian Heaven  US-Washington
# 7        519.0  1202-01-                     Hood      US-Oregon
# 8        521.0  1202-02-                Jefferson      US-Oregon
# 9        522.0  1202-03-         Blue Lake Crater      US-Oregon
# 10       523.0  1202-04-      Sand Mountain Field      US-Oregon
# 11       524.0  1202-05-               Washington      US-Oregon
# 12       525.0  1202-06-                  Belknap      US-Oregon
# ...

# %%
voldata[['NAME', 'LOCATION']]
# Out:
#                        NAME       LOCATION
# 0                     Baker  US-Washington
# 1              Glacier Peak  US-Washington
# 2                   Rainier  US-Washington
# 3                St. Helens  US-Washington
# 4                     Adams  US-Washington
# 5               West Crater  US-Washington
# 6             Indian Heaven  US-Washington
# 7                      Hood      US-Oregon
# 8                 Jefferson      US-Oregon
# 9          Blue Lake Crater      US-Oregon
# 10      Sand Mountain Field      US-Oregon
# 11               Washington      US-Oregon
# 12                  Belknap      US-Oregon
# 13       North Sister Field      US-Oregon
# 14             South Sister      US-Oregon
# 15                 Bachelor      US-Oregon
# 16         Newberry Volcano      US-Oregon
# 17               Davis Lake      US-Oregon
# 18            Devils Garden      US-Oregon
# 19           Cinnamon Butte      US-Oregon
# 20   Squaw Ridge Lava Field      US-Oregon
# ...

# %%
voldata.iloc[:,2:4]
# Out:
#                        NAME       LOCATION
# 0                     Baker  US-Washington
# 1              Glacier Peak  US-Washington
# 2                   Rainier  US-Washington
# 3                St. Helens  US-Washington
# 4                     Adams  US-Washington
# 5               West Crater  US-Washington
# 6             Indian Heaven  US-Washington
# 7                      Hood      US-Oregon
# 8                 Jefferson      US-Oregon
# 9          Blue Lake Crater      US-Oregon
# 10      Sand Mountain Field      US-Oregon
# 11               Washington      US-Oregon
# 12                  Belknap      US-Oregon
# 13       North Sister Field      US-Oregon
# 14             South Sister      US-Oregon
# 15                 Bachelor      US-Oregon
# 16         Newberry Volcano      US-Oregon
# 17               Davis Lake      US-Oregon
# 18            Devils Garden      US-Oregon
# 19           Cinnamon Butte      US-Oregon
# 20   Squaw Ridge Lava Field      US-Oregon
# ...

# %%
for name,location in zip(voldata.NAME, voldata.LOCATION):
    print(name+" "+location)
# Out:
# Baker US-Washington
# Glacier Peak US-Washington
# Rainier US-Washington
# St. Helens US-Washington
# Adams US-Washington
# West Crater US-Washington
# Indian Heaven US-Washington
# Hood US-Oregon
# Jefferson US-Oregon
# Blue Lake Crater US-Oregon
# Sand Mountain Field US-Oregon
# Washington US-Oregon
# Belknap US-Oregon
# North Sister Field US-Oregon
# South Sister US-Oregon
# Bachelor US-Oregon
# Newberry Volcano US-Oregon
# Davis Lake US-Oregon
# Devils Garden US-Oregon
# Cinnamon Butte US-Oregon
# Squaw Ridge Lava Field US-Oregon
# Four Craters Lava Field US-Oregon
# Crater Lake US-Oregon
# Yellowstone US-Wyoming
# Diamond Craters US-Oregon
# Jordan Craters US-Oregon
# Saddle Butte US-Oregon
# Craters of the Moon US-Idaho
# Hell's Half Acre US-Idaho
# Shoshone Lava Field US-Idaho
# Jackies Butte US-Oregon
# Medicine Lake US-California
# Wapi Lava Field US-Idaho
# Shasta US-California
# Brushy Butte US-California
# Big Cave US-California
# Twin Buttes US-California
# ...

# %%
for lt,ln,name in zip(latlist,lonlist,voldata.NAME):
    print(type(name))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
latlist=list(voldata["LAT"])
lonlist=list(voldata["LON"])

# %%
map1=folium.Map(location=[38.58,-99.09], zoom_start=6, tiles="Mapbox Bright")
fg1=folium.FeatureGroup(name="My Map")
for lt,ln,name,loc in zip(latlist,lonlist,voldata.NAME, voldata.LOCATION):
    fg1.add_child(folium.Marker(location = [lt, ln], popup=folium.Popup(name+" "+loc,parse_html=True), icon=folium.Icon(color='purple')))
    
map1.add_child(fg1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map1.save("map2.html")
