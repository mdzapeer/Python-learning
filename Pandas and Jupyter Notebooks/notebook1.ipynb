# %%
import pandas

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'etftest.json',
#  'notebook1.ipynb',
#  'physical_currency_list.csv',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
df1=pandas.read_csv("supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2=pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4=pandas.read_csv("supermarkets-commas.txt",)
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
etf=pandas.read_json("https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_WEEKLY&symbol=BTC&market=USD&apikey=K53QQNRE6X9S2YCI", )

# %%
etf
# Out:
#                                                                Meta Data  \
# 1. Information            Weekly Prices and Volumes for Digital Currency
# 2. Digital Currency Code                                             BTC
# 2014-04-13                                                           NaN
# 2014-04-20                                                           NaN
# 2014-04-27                                                           NaN
# 2014-05-04                                                           NaN
# 2014-05-11                                                           NaN
# 2014-05-18                                                           NaN
# 2014-05-25                                                           NaN
# 2014-06-01                                                           NaN
# 2014-06-08                                                           NaN
# 2014-06-15                                                           NaN
# ...

# %%
etf1=etf.drop("Meta Data", 1)

# %%
etf2=etf1.drop(etf1.index[-5:])

etf3=etf2.drop(etf2.index[:2])

# %%
etf3
# Out:
#                         Time Series (Digital Currency Weekly)
# 2014-04-13  {'1a. open (USD)': '462.12175864', '1b. open (...
# 2014-04-20  {'1a. open (USD)': '414.33989727', '1b. open (...
# 2014-04-27  {'1a. open (USD)': '497.31590211', '1b. open (...
# 2014-05-04  {'1a. open (USD)': '429.53545201', '1b. open (...
# 2014-05-11  {'1a. open (USD)': '434.63450656', '1b. open (...
# 2014-05-18  {'1a. open (USD)': '438.50854665', '1b. open (...
# 2014-05-25  {'1a. open (USD)': '445.48131574', '1b. open (...
# 2014-06-01  {'1a. open (USD)': '572.07065297', '1b. open (...
# 2014-06-08  {'1a. open (USD)': '628.12843904', '1b. open (...
# 2014-06-15  {'1a. open (USD)': '655.47343423', '1b. open (...
# 2014-06-22  {'1a. open (USD)': '591.17997666', '1b. open (...
# 2014-06-29  {'1a. open (USD)': '600.77697348', '1b. open (...
# 2014-07-06  {'1a. open (USD)': '600.15848060', '1b. open (...
# 2014-07-13  {'1a. open (USD)': '634.65927573', '1b. open (...
# ...

# %%
etf3.transpose()
# Out:
#                                                                               2014-04-13  \
# Time Series (Digital Currency Weekly)  {'1a. open (USD)': '462.12175864', '1b. open (...
#
#                                                                               2014-04-20  \
# Time Series (Digital Currency Weekly)  {'1a. open (USD)': '414.33989727', '1b. open (...
#
#                                                                               2014-04-27  \
# Time Series (Digital Currency Weekly)  {'1a. open (USD)': '497.31590211', '1b. open (...
#
#                                                                               2014-05-04  \
# Time Series (Digital Currency Weekly)  {'1a. open (USD)': '429.53545201', '1b. open (...
#
#                                                                               2014-05-11  \
# Time Series (Digital Currency Weekly)  {'1a. open (USD)': '434.63450656', '1b. open (...
#
# ...

# %%
etf4=etf3.transpose()

# %%
etf3
# Out:
#                         Time Series (Digital Currency Weekly)
# 2014-04-13  {'1a. open (USD)': '462.12175864', '1b. open (...
# 2014-04-20  {'1a. open (USD)': '414.33989727', '1b. open (...
# 2014-04-27  {'1a. open (USD)': '497.31590211', '1b. open (...
# 2014-05-04  {'1a. open (USD)': '429.53545201', '1b. open (...
# 2014-05-11  {'1a. open (USD)': '434.63450656', '1b. open (...
# 2014-05-18  {'1a. open (USD)': '438.50854665', '1b. open (...
# 2014-05-25  {'1a. open (USD)': '445.48131574', '1b. open (...
# 2014-06-01  {'1a. open (USD)': '572.07065297', '1b. open (...
# 2014-06-08  {'1a. open (USD)': '628.12843904', '1b. open (...
# 2014-06-15  {'1a. open (USD)': '655.47343423', '1b. open (...
# 2014-06-22  {'1a. open (USD)': '591.17997666', '1b. open (...
# 2014-06-29  {'1a. open (USD)': '600.77697348', '1b. open (...
# 2014-07-06  {'1a. open (USD)': '600.15848060', '1b. open (...
# 2014-07-13  {'1a. open (USD)': '634.65927573', '1b. open (...
# ...

# %%
dict1=etf3.loc["2014-04-13","Time Series (Digital Currency Weekly)"]

# %%
dict1
# Out:
# {'1a. open (USD)': '462.12175864',
#  '1b. open (USD)': '462.12175864',
#  '2a. high (USD)': '465.23847591',
#  '2b. high (USD)': '465.23847591',
#  '3a. low (USD)': '347.02732223',
#  '3b. low (USD)': '347.02732223',
#  '4a. close (USD)': '413.60539791',
#  '4b. close (USD)': '413.60539791',
#  '5. volume': '423951.56842000',
#  '6. market cap (USD)': '172191271.06600001'}

# %%
dict1.keys()
# Out:
# dict_keys(['1a. open (USD)', '1b. open (USD)', '2a. high (USD)', '2b. high (USD)', '3a. low (USD)', '3b. low (USD)', '4a. close (USD)', '4b. close (USD)', '5. volume', '6. market cap (USD)'])

# %%
etf3.iloc[0,0]
# Out:
# {'1a. open (USD)': '462.12175864',
#  '1b. open (USD)': '462.12175864',
#  '2a. high (USD)': '465.23847591',
#  '2b. high (USD)': '465.23847591',
#  '3a. low (USD)': '347.02732223',
#  '3b. low (USD)': '347.02732223',
#  '4a. close (USD)': '413.60539791',
#  '4b. close (USD)': '413.60539791',
#  '5. volume': '423951.56842000',
#  '6. market cap (USD)': '172191271.06600001'}

# %%
etf3.index[1]
# Out:
# '2014-04-20'

# %%
etf3.ix[0,0]
# Out:
# c:\users\mohammad_s\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# {'1a. open (USD)': '462.12175864',
#  '1b. open (USD)': '462.12175864',
#  '2a. high (USD)': '465.23847591',
#  '2b. high (USD)': '465.23847591',
#  '3a. low (USD)': '347.02732223',
#  '3b. low (USD)': '347.02732223',
#  '4a. close (USD)': '413.60539791',
#  '4b. close (USD)': '413.60539791',
#  '5. volume': '423951.56842000',
#  '6. market cap (USD)': '172191271.06600001'}

# %%
etf3
# Out:
#                         Time Series (Digital Currency Weekly)
# 2014-04-13  {'1a. open (USD)': '462.12175864', '1b. open (...
# 2014-04-20  {'1a. open (USD)': '414.33989727', '1b. open (...
# 2014-04-27  {'1a. open (USD)': '497.31590211', '1b. open (...
# 2014-05-04  {'1a. open (USD)': '429.53545201', '1b. open (...
# 2014-05-11  {'1a. open (USD)': '434.63450656', '1b. open (...
# 2014-05-18  {'1a. open (USD)': '438.50854665', '1b. open (...
# 2014-05-25  {'1a. open (USD)': '445.48131574', '1b. open (...
# 2014-06-01  {'1a. open (USD)': '572.07065297', '1b. open (...
# 2014-06-08  {'1a. open (USD)': '628.12843904', '1b. open (...
# 2014-06-15  {'1a. open (USD)': '655.47343423', '1b. open (...
# 2014-06-22  {'1a. open (USD)': '591.17997666', '1b. open (...
# 2014-06-29  {'1a. open (USD)': '600.77697348', '1b. open (...
# 2014-07-06  {'1a. open (USD)': '600.15848060', '1b. open (...
# 2014-07-13  {'1a. open (USD)': '634.65927573', '1b. open (...
# ...

# %%
import geopy

# %%
from geopy.geocoders import Nominatim

# %%
nom=Nominatim(scheme="http")

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, United States of America, (37.7529648, -122.4317141, 0.0))

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
type(nom)
# Out:
# geopy.geocoders.osm.Nominatim

# %%
df["Address"]=df["Address"] + ", "+df["City"]+", "+df["State"]+", "+df["Country"]

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0]
# Out:
# Location(3666, 21st Street, Noe Valley, SF, California, 94114, United States of America, (37.756488877551, -122.429343346939, 0.0))

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
